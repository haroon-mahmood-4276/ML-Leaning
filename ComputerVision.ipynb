# %% [markdown]
# # Computer Vision

# %% [markdown]
# ## Import Library

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
from PIL import Image

# %%
imagePath = 'images/3a7qam.jpg'

# %%
img = cv2.imread(imagePath)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img
# Out:
# array([[[109, 139,  85],
#         [112, 147,  81],
#         [113, 154,  76],
#         ...,
#         [ 70,  64,   4],
#         [ 76,  70,  20],
#         [ 62,  58,  13]],
#
#        [[115, 148,  93],
#         [126, 163,  96],
#         [124, 166,  84],
#         ...,
#         [ 96,  86,  24],
#         [101,  94,  40],
#         [ 73,  67,  19]],
#
#        [[115, 151,  89],
#         [127, 167,  94],
#         [117, 163,  75],
#         ...,
#         [113, 103,  34],
#         [119, 109,  48],
#         [ 79,  69,  16]],
#
#        ...,
#
#        [[102, 139,  62],
#         [100, 143,  54],
#         [ 95, 146,  43],
#         ...,
#         [  5,   1,   0],
#         [  6,   4,   5],
#         [  0,   0,   0]],
#
#        [[ 99, 140,  62],
#         [100, 144,  57],
#         [ 93, 145,  47],
#         ...,
#         [  4,   3,   1],
#         [  7,   6,   4],
#         [  0,   0,   0]],
#
#        [[ 99, 140,  64],
#         [100, 143,  61],
#         [ 94, 144,  49],
# ...

# %%
plt.imshow(img)
