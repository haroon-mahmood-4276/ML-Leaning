# %% [markdown]
# # Computer Vision

# %% [markdown]
# ## Import Library

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
from PIL import Image

# %%
img = cv2.imread('images/3a7qam.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img
# Out:
# array([[[124, 124, 124],
#         [129, 129, 129],
#         [133, 133, 133],
#         ...,
#         [ 59,  59,  59],
#         [ 66,  66,  66],
#         [ 54,  54,  54]],
#
#        [[132, 132, 132],
#         [144, 144, 144],
#         [144, 144, 144],
#         ...,
#         [ 82,  82,  82],
#         [ 90,  90,  90],
#         [ 63,  63,  63]],
#
#        [[133, 133, 133],
#         [147, 147, 147],
#         [139, 139, 139],
#         ...,
#         [ 98,  98,  98],
#         [105, 105, 105],
#         [ 66,  66,  66]],
#
#        ...,
#
#        [[119, 119, 119],
#         [120, 120, 120],
#         [119, 119, 119],
#         ...,
#         [  2,   2,   2],
#         [  5,   5,   5],
#         [  0,   0,   0]],
#
#        [[119, 119, 119],
#         [121, 121, 121],
#         [118, 118, 118],
#         ...,
#         [  3,   3,   3],
#         [  6,   6,   6],
#         [  0,   0,   0]],
#
#        [[119, 119, 119],
#         [121, 121, 121],
#         [118, 118, 118],
# ...

# %%
plt.imshow(img)
